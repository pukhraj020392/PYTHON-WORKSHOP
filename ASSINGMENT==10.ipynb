# %% [markdown]
# ### Pivot Table practice
#
# Dataset: SalesData.csv
# <br><br>
# Solve the below questions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
z = pd.read_csv('SalesData.csv')
z
# Out:
#      OrderDate   Region  Manager   SalesMan          Item  Units Unit_price  \
# 0   01-06-2018     East   Martha  Alexander    Television     95   1,198.00
# 1      1-23-18  Central  Hermann     Shelli  Home Theater     50        500
# 2   02-09-2018  Central  Hermann       Luis    Television     36   1,198.00
# 3      2-26-18  Central  Timothy      David    Cell Phone     27        225
# 4      3-15-18     West  Timothy    Stephen    Television     56   1,198.00
# 5   04-01-2018     East   Martha  Alexander  Home Theater     60        500
# 6      4-18-18  Central   Martha     Steven    Television     75   1,198.00
# 7   05-05-2018  Central  Hermann       Luis    Television     90   1,198.00
# 8      5-22-18     West  Douglas    Michael    Television     32   1,198.00
# 9   06-08-2018     East   Martha  Alexander  Home Theater     60        500
# 10     6-25-18  Central  Hermann      Sigal    Television     90   1,198.00
# ...

# %%
z.dtypes
# Out:
# OrderDate      object
# Region         object
# Manager        object
# SalesMan       object
# Item           object
# Units           int64
# Unit_price     object
# Sale_amt       object
# Unnamed: 8    float64
# Unnamed: 9    float64
# dtype: object

# %% [markdown]
# Q1. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise.

# %%
z.pivot_table(z, ['Region', 'Manager'], aggfunc = {'Sale_amt': sum})
# Out:
#                                                           Sale_amt
# Region  Manager
# Central Douglas                              25080,266.0043,500.00
#         Hermann  25,000.0043,128.001,07,820.001,07,820.0014,000...
#         Marth                                            14,000.00
#         Martha                         89,850.0079,068.0016,772.00
#         Timothy        6,075.0023,000.0063,494.0040,000.008,386.00
# East    Douglas                          40,500.003,375.004,329.00
#         Martha   1,13,810.0030,000.0030,000.0014,500.0041,930.0...
# West    Douglas                                 38,336.0028,500.00
#         Timothy                      67,088.003,500.0037517,100.00

# %% [markdown]
# Q2. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise

# %%
z.pivot_table(z, ['Region','SalesMan', 'Manager'], aggfunc = {'Sale_amt': sum})
# Out:
#                                                                     Sale_amt
# Region  SalesMan  Manager
# Central David     Timothy        6,075.0023,000.0063,494.0040,000.008,386.00
#         John      Douglas                              25080,266.0043,500.00
#         Luis      Hermann      43,128.001,07,820.002,925.005,500.0047,000.00
#         Shelli    Hermann                       25,000.005,616.006252,457.00
#         Sigal     Hermann                       1,07,820.0014,000.003,217.50
#         Steven    Marth                                            14,000.00
#                   Martha                         89,850.0079,068.0016,772.00
# East    Alexander Martha   1,13,810.0030,000.0030,000.0041,930.0093614,40...
#         Diana     Martha                                  14,500.0021,600.00
#         Karen     Douglas                          40,500.003,375.004,329.00
# West    Michael   Douglas                                 38,336.0028,500.00
# ...

# %% [markdown]
# Q3. Write a Pandas program to create a Pivot table and find the item wise unit sold

# %%
z.pivot_table('Units','Item',aggfunc = {'Units': sum})
# Out:
#               Units
# Item
# Cell Phone      278
# Desk             10
# Home Theater    722
# Television      716
# Video Games     395

# %% [markdown]
# Q4. Write a Pandas program to create a Pivot table and find the region wise total sale

# %%
z.pivot_table(z,['Region'], aggfunc = {'Unit_price': sum})
# Out:
#                                                 Unit_price
# Region
# Central  5001,198.002251,198.001,198.001,198.0012550058...
# East     1,198.005005005005001,198.0058.522522558.55002...
# West                          1,198.001,198.00500125225500

# %% [markdown]
# Q5. Write a Pandas program to create a Pivot table and find the region wise, item wise unit sold.

# %%
z.pivot_table(z,['Region','Item'],aggfunc = {'Units': sum})
# Out:
#                       Units
# Region  Item
# Central Cell Phone       27
#         Desk              7
#         Home Theater    424
#         Television      498
#         Video Games     243
# East    Cell Phone      175
#         Home Theater    234
#         Television      130
#         Video Games     152
# West    Cell Phone       76
#         Desk              3
#         Home Theater     64
#         Television       88

# %% [markdown]
# Q6. Write a Pandas program to create a Pivot table and count the manager wise sale and mean value of sale amount

# %%
data = pd.DataFrame(z)
data
# Out:
#      OrderDate   Region  Manager   SalesMan          Item  Units Unit_price  \
# 0   01-06-2018     East   Martha  Alexander    Television     95   1,198.00
# 1      1-23-18  Central  Hermann     Shelli  Home Theater     50        500
# 2   02-09-2018  Central  Hermann       Luis    Television     36   1,198.00
# 3      2-26-18  Central  Timothy      David    Cell Phone     27        225
# 4      3-15-18     West  Timothy    Stephen    Television     56   1,198.00
# 5   04-01-2018     East   Martha  Alexander  Home Theater     60        500
# 6      4-18-18  Central   Martha     Steven    Television     75   1,198.00
# 7   05-05-2018  Central  Hermann       Luis    Television     90   1,198.00
# 8      5-22-18     West  Douglas    Michael    Television     32   1,198.00
# 9   06-08-2018     East   Martha  Alexander  Home Theater     60        500
# 10     6-25-18  Central  Hermann      Sigal    Television     90   1,198.00
# ...

# %%
z['Sale_amt']
# Out:
# 0     1,13,810.00
# 1       25,000.00
# 2       43,128.00
# 3        6,075.00
# 4       67,088.00
# 5       30,000.00
# 6       89,850.00
# 7     1,07,820.00
# 8       38,336.00
# 9       30,000.00
# 10    1,07,820.00
# 11      14,500.00
# 12      40,500.00
# 13      41,930.00
# 14            250
# 15            936
# 16      14,000.00
# 17      14,400.00
# 18       3,375.00
# 19       5,616.00
# 20      80,266.00
# 21       4,329.00
# 22      23,000.00
# 23      43,500.00
# 24       2,000.00
# 25       3,500.00
# 26       2,925.00
# 27      79,068.00
# 28      21,600.00
# 29      63,494.00
# 30      40,000.00
# 31            625
# 32       3,627.00
# 33       3,217.50
# 34       2,457.00
# 35            375
# 36       8,386.00
# 37      17,100.00
# 38      28,500.00
# 39      16,772.00
# 40       5,500.00
# 41      47,000.00
# 42      14,000.00
# Name: Sale_amt, dtype: object

# %%
def convert_currency(val):
    """
    Convert the string number value to a float
     - Remove $
     - Remove commas
     - Convert to float type
    """
    new_val = val.replace(',','')
    return float(new_val)

data['Sale_amt'].apply(convert_currency).mean()
# Out:
# 30364.54651162791

# %% [markdown]
# respected sir i have convert the dtype of sale_amt columns to float type but still i am not able to get aggfunc mean value of sale

# %%
data.pivot_table(data,['Manager','Units'], aggfunc={'Sale_amt':'sum'})
# Out:
#                              Sale_amt
# Manager Units
# Douglas 2                         250
#         15                   3,375.00
#         32                  38,336.00
#         57                  28,500.00
#         67                  80,266.00
#         74                   4,329.00
#         81                  40,500.00
#         87                  43,500.00
# Hermann 5                         625
#         11                   5,500.00
#         28                  14,000.00
#         36                  43,128.00
#         42                   2,457.00
#         50          25,000.002,925.00
#         55                   3,217.50
#         90     1,07,820.001,07,820.00
#         94                  47,000.00
#         96                   5,616.00
# Marth   28                  14,000.00
# Martha  4                    2,000.00
#         14                  16,772.00
#         16                        936
#         29                  14,500.00
# ...

# %%
data.dtypes
# Out:
# OrderDate      object
# Region         object
# Manager        object
# SalesMan       object
# Item           object
# Units           int64
# Unit_price     object
# Sale_amt       object
# Unnamed: 8    float64
# Unnamed: 9    float64
# dtype: object

# %%
z.dtypes
# Out:
# OrderDate      object
# Region         object
# Manager        object
# SalesMan       object
# Item           object
# Units           int64
# Unit_price     object
# Sale_amt       object
# Unnamed: 8    float64
# Unnamed: 9    float64
# dtype: object

# %% [markdown]
# Q7. Write a Pandas program to create a Pivot table and find manager wise, salesman wise total sale and also display the sum of all sale amount at the bottom

# %%
pd.pivot_table(z, index = ["Manager", "SalesMan"], values = ["Units","Sale_amt"], aggfunc = [np.sum], fill_value = 0, margins = True)
# Out:
#                     sum
#                   Units
# Manager SalesMan
# Douglas John        156
#         Karen       170
#         Michael      89
# Hermann Luis        281
#         Shelli      193
#         Sigal       173
# Marth   Steven       28
# Martha  Alexander   396
#         Diana       125
#         Steven      155
# Timothy David       213
#         Stephen     142
# All                2121

# %% [markdown]
# Q8. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise where Manager = "Douglas"

# %%
x = z.pivot_table('Sale_amt',index=["Region","Manager","SalesMan"], aggfunc = {'Sale_amt': sum})
x.query('Manager == ["Douglas"]')
# Out:
#                                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John          25080,266.0043,500.00
# East    Douglas Karen     40,500.003,375.004,329.00
# West    Douglas Michael          38,336.0028,500.00

# %% [markdown]
# Q9. Write a Pandas program to create a Pivot table and find the region wise Television and Home Theater sold

# %%
b = pd.pivot_table(z,index=["Region", "Item"], values="Units")
b.query('Item == ["Television","Home Theater"]')
# Out:
#                           Units
# Region  Item
# Central Home Theater  53.000000
#         Television    55.333333
# East    Home Theater  46.800000
#         Television    65.000000
# West    Home Theater  32.000000
#         Television    44.000000
