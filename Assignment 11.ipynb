# %% [markdown]
# ### Practice Assignment for Data Visualization
#
# You may use:
# * matplotlib
# * seaborn
#
# **Dataset:** Iris Dataset & <a href="https://www.kaggle.com/zynicide/wine-reviews#winemag-data-130k-v2.csv">Wine Reviews Dataset</a>
#
# **Note:** Particular questions are not provided in this assignment. Try to interpret the plot given in the expected output and write code for the same accordingly.

# %% [markdown]
# ##### Plot 1

# %%
#expected output
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %% [markdown]
# ##### Plot 2

# %%
#expected output
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A105F93BA8>,
# ...
#       dtype=object)

# %% [markdown]
# ##### Plot 3

# %%
#expected output

# %% [markdown]
# ##### Plot 4

# %%
#expected output
# Out:
# (4, 10)

# %% [markdown]
# ##### Plot 5

# %%
#expected output
# Out:
# Text(0.5, 1, '')

# %% [markdown]
# ##### Plot 6

# %%
#expected output
# Out:
# Text(0, 0.5, 'Points')

# %% [markdown]
# ##### Plot 7

# %%
#expected output
# Out:
# Text(0, 0.5, 'Avg. Price')
