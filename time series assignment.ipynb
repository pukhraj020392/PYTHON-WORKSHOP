# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
from dateutil import parser
import matplotlib.pyplot as plt
import seaborn as sb

# %%
t = pd.read_csv('AAPL.csv')
t
# Out:
#             date      open      high       low     close     volume  Name
# 0     2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 1     2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2     2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 3     2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 4     2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...          ...       ...       ...       ...       ...        ...   ...
# 1254  2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 1255  2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 1256  2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 1257  2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 1258  2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 7 columns]

# %%
t.head(10)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 5  2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL
# 6  2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL
# 7  2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL
# 8  2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL
# 9  2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL

# %%
t.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
t['date'] = pd.to_datetime(t['date'])
t.dtypes
# Out:
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# Name              object
# dtype: object

# %%
t = t.set_index('date')
t.head(10)
# Out:
#                open     high      low    close     volume  Name
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL
# 2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL
# 2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL
# 2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL
# 2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL

# %%
t.index
# Out:
# DatetimeIndex(['2013-02-08', '2013-02-11', '2013-02-12', '2013-02-13',
#                '2013-02-14', '2013-02-15', '2013-02-19', '2013-02-20',
#                '2013-02-21', '2013-02-22',
#                ...
#                '2018-01-25', '2018-01-26', '2018-01-29', '2018-01-30',
#                '2018-01-31', '2018-02-01', '2018-02-02', '2018-02-05',
#                '2018-02-06', '2018-02-07'],
#               dtype='datetime64[ns]', name='date', length=1259, freq=None)

# %%
t['Year'] = t.index.year
t.head()
# Out:
#                open     high      low    close     volume  Name  Year
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL  2013
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL  2013
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL  2013
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL  2013
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL  2013

# %%
t['Month'] = t.index.month
t.head()
# Out:
#                open     high      low    close     volume  Name  Year  Month
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL  2013      2
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL  2013      2
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL  2013      2
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL  2013      2
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL  2013      2

# %%
t['Weekday Name'] = t.index.weekday_name
t.head()
# Out:
#                open     high      low    close     volume  Name  Year  Month  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL  2013      2
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL  2013      2
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL  2013      2
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL  2013      2
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL  2013      2
#
#            Weekday Name
# date
# 2013-02-08       Friday
# 2013-02-11       Monday
# 2013-02-12      Tuesday
# 2013-02-13    Wednesday
# 2013-02-14     Thursday

# %%
t.loc['2013-05-08']
# Out:
# open              65.5771
# high              66.4814
# low               65.1156
# close             66.2628
# volume          118010781
# Name                 AAPL
# Year                 2013
# Month                   5
# Weekday Name    Wednesday
# Name: 2013-05-08 00:00:00, dtype: object

# %%
t.loc['2013-01-11':'2018-04-12']
# Out:
#                 open      high       low     close     volume  Name  Year  \
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL  2013
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL  2013
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL  2013
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL  2013
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL  2013
# ...              ...       ...       ...       ...        ...   ...   ...
# 2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL  2018
# 2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL  2018
# 2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL  2018
# 2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL  2018
# 2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL  2018
#
#             Month Weekday Name
# date
# 2013-02-08      2       Friday
# 2013-02-11      2       Monday
# 2013-02-12      2      Tuesday
# 2013-02-13      2    Wednesday
# 2013-02-14      2     Thursday
# ...           ...          ...
# 2018-02-01      2     Thursday
# 2018-02-02      2       Friday
# 2018-02-05      2       Monday
# 2018-02-06      2      Tuesday
# 2018-02-07      2    Wednesday
#
# [1259 rows x 9 columns]

# %%
t['2013-03']
# Out:
#                open     high      low    close     volume  Name  Year  Month  \
# date
# 2013-03-01  62.5714  62.5971  61.4257  61.4957  137899041  AAPL  2013      3
# 2013-03-04  61.1142  61.1714  59.8571  60.0071  145406366  AAPL  2013      3
# 2013-03-05  60.2114  62.1699  60.1071  61.5919  159298020  AAPL  2013      3
# 2013-03-06  62.0728  62.1785  60.6328  60.8088  114903180  AAPL  2013      3
# 2013-03-07  60.6428  61.7157  60.1514  61.5117  116992841  AAPL  2013      3
# 2013-03-08  61.3999  62.2042  61.2299  61.6742   97854442  AAPL  2013      3
# 2013-03-11  61.3928  62.7157  60.7342  62.5528  118272126  AAPL  2013      3
# 2013-03-12  62.2285  62.6971  61.0814  61.2042  116268341  AAPL  2013      3
# 2013-03-13  61.2071  62.0714  60.7657  61.1928  101369051  AAPL  2013      3
# 2013-03-14  61.8328  62.0914  61.4928  61.7857   75834906  AAPL  2013      3
# 2013-03-15  62.5614  63.4614  62.4642  63.3799  160710606  AAPL  2013      3
# 2013-03-18  63.0642  65.3514  63.0285  65.1028  150441144  AAPL  2013      3
# 2013-03-19  65.6428  65.8528  64.0714  64.9271  131531708  AAPL  2013      3
# 2013-03-20  65.3456  65.3756  64.2271  64.5828   77016849  AAPL  2013      3
# 2013-03-21  64.3171  65.4256  64.2999  64.6756   95493524  AAPL  2013      3
# 2013-03-22  64.9399  66.0142  64.7299  65.9871   98570591  AAPL  2013      3
# 2013-03-25  66.3842  67.1356  65.9685  66.2256  125073165  AAPL  2013      3
# 2013-03-26  66.4914  66.5485  65.7899  65.8765   73428208  AAPL  2013      3
# 2013-03-27  65.2085  65.2571  64.3899  64.5828   81854409  AAPL  2013      3
# 2013-03-28  64.2599  64.5455  63.0885  63.2371  110698007  AAPL  2013      3
#
#            Weekday Name
# date
# 2013-03-01       Friday
# 2013-03-04       Monday
# 2013-03-05      Tuesday
# 2013-03-06    Wednesday
# 2013-03-07     Thursday
# 2013-03-08       Friday
# 2013-03-11       Monday
# 2013-03-12      Tuesday
# 2013-03-13    Wednesday
# 2013-03-14     Thursday
# 2013-03-15       Friday
# 2013-03-18       Monday
# 2013-03-19      Tuesday
# 2013-03-20    Wednesday
# 2013-03-21     Thursday
# 2013-03-22       Friday
# 2013-03-25       Monday
# 2013-03-26      Tuesday
# 2013-03-27    Wednesday
# 2013-03-28     Thursday

# %%
t['high'].plot()

# %%
t['low'].plot()

# %%
t['volume'].plot()

# %%
t.plot()
plt.ylabel('Hourly Bicycle Count');

# %%
weekly = t.resample('W').sum()
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Weekly bicycle count');

# %%
daily = t.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':', '--', '-'])
plt.ylabel('mean hourly count');
